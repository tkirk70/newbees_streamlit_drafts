# %% [markdown]
# # Jupyter Playground - ESPN Fanstasy Football API

# %%
# figure out how to make this df without excel.

import pandas as pd

df = pd.read_excel('season_2021.xlsx', sheet_name='combined_2021')

teams = df.columns.to_list()

weeks = df.Week.to_list()

df.set_index(['Week'], inplace = True)

# Python program to generate a heatmap
# which displays the value in each cell
# corresponding to the given dataframe

# import required libraries
import pandas as pd

# displaying dataframe as an heatmap
# with diverging colourmap as virdis
df.style.background_gradient(cmap ='viridis')\
    .set_properties(**{'font-size': '11px'})
# Out:
# <style type="text/css">
# #T_86f27_row0_col0, #T_86f27_row14_col7 {
#   background-color: #38b977;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row0_col1, #T_86f27_row6_col2 {
#   background-color: #306a8e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row0_col2, #T_86f27_row2_col7, #T_86f27_row5_col2, #T_86f27_row6_col5, #T_86f27_row8_col3, #T_86f27_row10_col4, #T_86f27_row11_col1, #T_86f27_row14_col0, #T_86f27_row14_col8, #T_86f27_row16_col6, #T_86f27_row16_col9 {
#   background-color: #440154;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row0_col3, #T_86f27_row1_col9 {
#   background-color: #26828e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row0_col4, #T_86f27_row5_col4, #T_86f27_row5_col9 {
#   background-color: #dae319;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row0_col5 {
#   background-color: #69cd5b;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row0_col6, #T_86f27_row12_col7 {
#   background-color: #48c16e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row0_col7, #T_86f27_row12_col5 {
#   background-color: #2eb37c;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row0_col8 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row0_col9, #T_86f27_row7_col6 {
#   background-color: #c0df25;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row1_col0, #T_86f27_row3_col7, #T_86f27_row4_col1, #T_86f27_row4_col2, #T_86f27_row4_col8, #T_86f27_row5_col3, #T_86f27_row6_col6, #T_86f27_row11_col9, #T_86f27_row14_col5, #T_86f27_row16_col4 {
#   background-color: #fde725;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row1_col1, #T_86f27_row15_col5 {
#   background-color: #40bd72;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row1_col2, #T_86f27_row1_col6 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row1_col3 {
#   background-color: #cde11d;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row1_col4, #T_86f27_row12_col4 {
#   background-color: #50c46a;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row1_col5 {
#   background-color: #2cb17e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row1_col7 {
#   background-color: #3b528b;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row1_col8, #T_86f27_row6_col8 {
#   background-color: #2c728e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row2_col0, #T_86f27_row2_col8 {
#   background-color: #3aba76;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row2_col1, #T_86f27_row6_col0 {
#   background-color: #52c569;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row2_col2 {
#   background-color: #20a486;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row2_col3, #T_86f27_row4_col4 {
#   background-color: #1fa287;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row2_col4, #T_86f27_row4_col9 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row2_col5 {
#   background-color: #65cb5e;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row2_col6 {
#   background-color: #c2df23;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row2_col9 {
#   background-color: #365d8d;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row3_col0, #T_86f27_row10_col5 {
#   background-color: #453781;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row3_col1 {
#   background-color: #33638d;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row3_col2 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row3_col3 {
#   background-color: #1fa188;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row3_col4, #T_86f27_row6_col1, #T_86f27_row13_col6 {
#   background-color: #31b57b;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row3_col5, #T_86f27_row7_col3, #T_86f27_row9_col3, #T_86f27_row10_col7 {
#   background-color: #21a685;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row3_col6 {
#   background-color: #56c667;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row3_col8 {
#   background-color: #26818e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row3_col9 {
#   background-color: #75d054;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row4_col0 {
#   background-color: #95d840;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row4_col3 {
#   background-color: #30698e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row4_col5 {
#   background-color: #a8db34;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row4_col6 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row4_col7 {
#   background-color: #46c06f;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row5_col0 {
#   background-color: #414487;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row5_col1, #T_86f27_row13_col1 {
#   background-color: #23898e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row5_col5, #T_86f27_row8_col8 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row5_col6 {
#   background-color: #32b67a;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row5_col7 {
#   background-color: #90d743;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row5_col8 {
#   background-color: #31678e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row6_col3 {
#   background-color: #37b878;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row6_col4 {
#   background-color: #2db27d;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row6_col7, #T_86f27_row8_col5, #T_86f27_row12_col9 {
#   background-color: #29798e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row6_col9 {
#   background-color: #aadc32;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row7_col0 {
#   background-color: #54c568;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row7_col1, #T_86f27_row11_col0 {
#   background-color: #2d708e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row7_col2, #T_86f27_row11_col7 {
#   background-color: #355f8d;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row7_col4 {
#   background-color: #482576;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row7_col5 {
#   background-color: #39558c;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row7_col7, #T_86f27_row9_col5 {
#   background-color: #375a8c;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row7_col8 {
#   background-color: #453581;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row7_col9, #T_86f27_row8_col7 {
#   background-color: #228c8d;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row8_col0 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row8_col1 {
#   background-color: #46327e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row8_col2, #T_86f27_row10_col8, #T_86f27_row14_col9 {
#   background-color: #355e8d;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row8_col4 {
#   background-color: #460b5e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row8_col6 {
#   background-color: #25848e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row8_col9 {
#   background-color: #20a386;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row9_col0, #T_86f27_row12_col3 {
#   background-color: #218e8d;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row9_col1 {
#   background-color: #1f978b;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row9_col2 {
#   background-color: #471063;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row9_col4, #T_86f27_row9_col6 {
#   background-color: #472a7a;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row9_col7, #T_86f27_row16_col8 {
#   background-color: #23888e;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row9_col8 {
#   background-color: #424186;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row9_col9 {
#   background-color: #b0dd2f;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row10_col0 {
#   background-color: #7ad151;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row10_col1, #T_86f27_row12_col0 {
#   background-color: #35b779;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row10_col2 {
#   background-color: #addc30;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row10_col3 {
#   background-color: #48186a;
#   color: #f1f1f1;
#   font-size: 11px;
# }
# #T_86f27_row10_col6 {
#   background-color: #d8e219;
#   color: #000000;
#   font-size: 11px;
# }
# #T_86f27_row10_col9, #T_86f27_row13_col8, #T_86f27_row16_col5 {
#   background-colo

# %%
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as pl

# %%
# Python program to generate a heatmap
# which represents panda dataframe
# in colour coding schemes

# import required libraries
import matplotlib.pyplot as plt
import pandas as pd


# Displaying dataframe as an heatmap
# with diverging colourmap as viridis
plt.imshow(df, cmap ="viridis")

# Displaying a color bar to understand
# which color represents which range of data
plt.colorbar()

# Assigning labels of x-axis
# according to dataframe
plt.xticks(range(10), df.columns)

# Assigning labels of y-axis
# according to dataframe
plt.yticks(range(len(df)), df.index)

# Displaying the figure
plt.show()

# %%
pip-compile requirements.in
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Usage:
#   C:\ProgramData\Anaconda3\python.exe -m pip <command> [options]
#
# no such option: -c
